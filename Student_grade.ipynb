# %% [markdown]
# <a href="https://colab.research.google.com/github/VASAVI1231/student-grade-calculator/blob/main/Student_grade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Grade Calculator
# Internship Task 2

print(" STUDENT GRADE CALCULATOR ")

# Get student name
name = input("Enter student name: ")

# Get number of subjects
while True:
    try:
        subjects = int(input("Enter number of subjects: "))

        if subjects > 0:
            break
        else:
            print("Number of subjects must be greater than 0.")

    except ValueError:
        print("Please enter a valid number.")

# Store marks
marks = []

# Get marks for each subject
for i in range(subjects):

    while True:
        try:
            mark = float(input(f"Enter marks for subject {i + 1}: "))

            if 0 <= mark <= 100:
                marks.append(mark)
                break
            else:
                print("Marks must be between 0 and 100.")

        except ValueError:
            print("Please enter valid numeric marks.")

# Calculate total and average
total = sum(marks)
maximum = subjects * 100
average = total / subjects

# Calculate grade
if average >= 90:
    grade = "A"
elif average >= 80:
    grade = "B"
elif average >= 70:
    grade = "C"
elif average >= 60:
    grade = "D"
else:
    grade = "F"

# Display results
print("\n STUDENT RESULT ")

print("Student Name:", name)
print("Total Marks:", total, "/", maximum)
print("Average Percentage:", round(average, 2), "%")
print("Grade:", grade)
# Out:
#  STUDENT GRADE CALCULATOR
# Enter student name: Vasavi
# Enter number of subjects: 6
# Enter marks for subject 1: 99
# Enter marks for subject 2: 56
# Enter marks for subject 3: 68
# Enter marks for subject 4: 71
# Enter marks for subject 5: 84
# Enter marks for subject 6: 75
#
#  STUDENT RESULT
# Student Name: Vasavi
# Total Marks: 453.0 / 600
# Average Percentage: 75.5 %
# Grade: C
